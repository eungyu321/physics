# %% [markdown]
# <a href="https://colab.research.google.com/github/eungyu321/physics/blob/20250312/%EA%B7%B9%EC%A2%8C%ED%91%9C_%EC%A7%81%EA%B5%90%EC%A2%8C%ED%91%9C_%EB%B3%80%ED%99%98_%ED%8C%8C%EC%9D%B4%EC%8D%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math #수학 함수를 사용하기 위해서 라이브러리 추가

angle_degree=30

angle_radian=angle_degree*math.pi/180

print("angle_radian:",angle_radian)
# Out:
# angle_radian: 0.5235987755982988

# %%
math.cos(angle_radian)
# Out:
# 0.8660254037844387

# %%
math.sin(angle_radian)
# Out:
# 0.49999999999999994

# %%
math.tan(angle_radian)
# Out:
# 0.5773502691896257

# %%
x,y=1.0,2.0

# %%
r = math.sqrt(x**2+y**2)
theta_raidan=math.atan2(y,x)

print(r,theta_raidan)
# Out:
# 2.23606797749979 1.1071487177940904

# %%
r,angle=10,30
r=10
angle_degree=30

x=r*math.cos(angle_radian)
y=angle*math.sin(angle_radian)

print(x,y)
# Out:
# 8.660254037844387 14.999999999999998
